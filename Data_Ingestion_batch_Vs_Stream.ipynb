# %% [markdown]
# <a href="https://colab.research.google.com/github/Sereenamariyam/Data-Analysis/blob/main/Data_Ingestion_batch_Vs_Stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Batch Ingestion (All-at-Once)

# %%
import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/velicki/Weather_Data_Analysis_Project/main/Weather_Data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#PREPROCESSING

# Rename columns for easier access
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('/', '_')

# Convert Date/Time to datetime object
df['Date_Time'] = pd.to_datetime(df['Date_Time'], errors='coerce')

# Drop rows with missing Date_Time or Temp_C
df = df.dropna(subset=['Date_Time', 'Temp_C'])

# Optional: Convert temperature to numeric
df['Temp_C'] = pd.to_numeric(df['Temp_C'], errors='coerce')

df.shape
df.head()
# Out:
#             Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_%  Wind_Speed_km_h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Stream Ingestion (Row-by-Row Simulation)

# %%
import pandas as pd
import time

# Step 1: Load the original data
url = "https://raw.githubusercontent.com/velicki/Weather_Data_Analysis_Project/refs/heads/main/Weather_Data.csv"
df = pd.read_csv(url)

# PREPROCESSING (added for streaming section)
# Rename columns for easier access
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('/', '_')

# Convert Date/Time to datetime object
df['Date_Time'] = pd.to_datetime(df['Date_Time'], errors='coerce')

# Drop rows with missing Date_Time or Temp_C
df = df.dropna(subset=['Date_Time', 'Temp_C'])

# Optional: Convert temperature to numeric
df['Temp_C'] = pd.to_numeric(df['Temp_C'], errors='coerce')

# %%
def alert_high_temp(row):
    if row['Temp_C'] > 5:
        print(f"⚠️ ALERT: High temperature detected at {row['Date_Time']} - {row['Temp_C']}°C")

# Apply during streaming
def stream_with_alert(data, delay=0.5):
    for idx, row in data.iterrows():
        # print(f"{row['Date_Time']} - Temp: {row['Temp_C']}°C")
        print(f"Streaming row {idx} → {row.to_dict()}")
        alert_high_temp(row)
        time.sleep(delay)

# %%
stream_with_alert(df)
# Out:
# Streaming row 0 → {'Date_Time': Timestamp('2012-01-01 00:00:00'), 'Temp_C': -1.8, 'Dew_Point_Temp_C': -3.9, 'Rel_Hum_%': 86, 'Wind_Speed_km_h': 4, 'Visibility_km': 8.0, 'Press_kPa': 101.24, 'Weather': 'Fog'}
# Streaming row 1 → {'Date_Time': Timestamp('2012-01-01 01:00:00'), 'Temp_C': -1.8, 'Dew_Point_Temp_C': -3.7, 'Rel_Hum_%': 87, 'Wind_Speed_km_h': 4, 'Visibility_km': 8.0, 'Press_kPa': 101.24, 'Weather': 'Fog'}
# Streaming row 2 → {'Date_Time': Timestamp('2012-01-01 02:00:00'), 'Temp_C': -1.8, 'Dew_Point_Temp_C': -3.4, 'Rel_Hum_%': 89, 'Wind_Speed_km_h': 7, 'Visibility_km': 4.0, 'Press_kPa': 101.26, 'Weather': 'Freezing Drizzle,Fog'}
# Streaming row 3 → {'Date_Time': Timestamp('2012-01-01 03:00:00'), 'Temp_C': -1.5, 'Dew_Point_Temp_C': -3.2, 'Rel_Hum_%': 88, 'Wind_Speed_km_h': 6, 'Visibility_km': 4.0, 'Press_kPa': 101.27, 'Weather': 'Freezing Drizzle,Fog'}
# Streaming row 4 → {'Date_Time': Timestamp('2012-01-01 04:00:00'), 'Temp_C': -1.5, 'Dew_Point_Temp_C': -3.3, 'Rel_Hum_%': 88, 'Wind_Speed_km_h': 7, 'Visibility_km': 4.8, 'Press_kPa': 101.23, 'Weather': 'Fog'}
# Streaming row 5 → {'Date_Time': Timestamp('2012-01-01 05:00:00'), 'Temp_C': -1.4, 'Dew_Point_Temp_C': -3.3, 'Rel_Hum_%': 87, 'Wind_Speed_km_h': 9, 'Visibility_km': 6.4, 'Press_kPa': 101.27, 'Weather': 'Fog'}
# Streaming row 6 → {'Date_Time': Timestamp('2012-01-01 06:00:00'), 'Temp_C': -1.5, 'Dew_Point_Temp_C': -3.1, 'Rel_Hum_%': 89, 'Wind_Speed_km_h': 7, 'Visibility_km': 6.4, 'Press_kPa': 101.29, 'Weather': 'Fog'}
# Streaming row 7 → {'Date_Time': Timestamp('2012-01-01 07:00:00'), 'Temp_C': -1.4, 'Dew_Point_Temp_C': -3.6, 'Rel_Hum_%': 85, 'Wind_Speed_km_h': 7, 'Visibility_km': 8.0, 'Press_kPa': 101.26, 'Weather': 'Fog'}
# Streaming row 8 → {'Date_Time': Timestamp('2012-01-01 08:00:00'), 'Temp_C': -1.4, 'Dew_Point_Temp_C': -3.6, 'Rel_Hum_%': 85, 'Wind_Speed_km_h': 9, 'Visibility_km': 8.0, 'Press_kPa': 101.23, 'Weather': 'Fog'}
# Streaming row 9 → {'Date_Time': Timestamp('2012-01-01 09:00:00'), 'Temp_C': -1.3, 'Dew_Point_Temp_C': -3.1, 'Rel_Hum_%': 88, 'Wind_Speed_km_h': 15, 'Visibility_km': 4.0, 'Press_kPa': 101.2, 'Weather': 'Fog'}
# Streaming row 10 → {'Date_Time': Timestamp('2012-01-01 10:00:00'), 'Temp_C': -1.0, 'Dew_Point_Temp_C': -2.3, 'Rel_Hum_%': 91, 'Wind_Speed_km_h': 9, 'Visibility_km': 1.2, 'Press_kPa': 101.15, 'Weather': 'Fog'}
# Streaming row 11 → {'Date_Time': Timestamp('2012-01-01 11:00:00'), 'Temp_C': -0.5, 'Dew_Point_Temp_C': -2.1, 'Rel_Hum_%': 89, 'Wind_Speed_km_h': 7, 'Visibility_km': 4.0, 'Press_kPa': 100.98, 'Weather': 'Fog'}
# Streaming row 12 → {'Date_Time': Timestamp('2012-01-01 12:00:00'), 'Temp_C': -0.2, 'Dew_Point_Temp_C': -2.0, 'Rel_Hum_%': 88, 'Wind_Speed_km_h': 9, 'Visibility_km': 4.8, 'Press_kPa': 100.79, 'Weather': 'Fog'}
# Streaming row 13 → {'Date_Time': Timestamp('2012-01-01 13:00:00'), 'Temp_C': 0.2, 'Dew_Point_Temp_C': -1.7, 'Rel_Hum_%': 87, 'Wind_Speed_km_h': 13, 'Visibility_km': 4.8, 'Press_kPa': 100.58, 'Weather': 'Fog'}
# Streaming row 14 → {'Date_Time': Timestamp('2012-01-01 14:00:00'), 'Temp_C': 0.8, 'Dew_Point_Temp_C': -1.1, 'Rel_Hum_%': 87, 'Wind_Speed_km_h': 20, 'Visibility_km': 4.8, 'Press_kPa': 100.31, 'Weather': 'Fog'}
# Streaming row 15 → {'Date_Time': Timestamp('2012-01-01 15:00:00'), 'Temp_C': 1.8, 'Dew_Point_Temp_C': -0.4, 'Rel_Hum_%': 85, 'Wind_Speed_km_h': 22, 'Visibility_km': 6.4, 'Press_kPa': 100.07, 'Weather': 'Fog'}
# Streaming row 16 → {'Date_Time': Timestamp('2012-01-01 16:00:00'), 'Temp_C': 2.6, 'Dew_Point_Temp_C': -0.2, 'Rel_Hum_%': 82, 'Wind_Speed_km_h': 13, 'Visibility_km': 12.9, 'Press_kPa': 99.93, 'Weather': 'Mostly Cloudy'}
# Streaming row 17 → {'Date_Time': Timestamp('2012-01-01 17:00:00'), 'Temp_C': 3.0, 'Dew_Point_Temp_C': 0.0, 'Rel_Hum_%': 81, 'Wind_Speed_km_h': 13, 'Visibility_km': 16.1, 'Press_kPa': 99.81, 'Weather': 'Cloudy'}
# Streaming row 18 → {'Date_Time': Timestamp('2012-01-01 18:00:00'), 'Temp_C': 3.8, 'Dew_Point_Temp_C': 1.0, 'Rel_Hum_%': 82, 'Wind_Speed_km_h': 15, 'Visibility_km': 12.9, 'Press_kPa': 99.74, 'Weather': 'Rain'}
# Streaming row 19 → {'Date_Time': Timestamp('2012-01-01 19:00:00'), 'Temp_C': 3.1, 'Dew_Point_Temp_C': 1.3, 'Rel_Hum_%': 88, 'Wind_Speed_km_h': 15, 'Visibility_km': 12.9, 'Press_kPa': 99.68, 'Weather': 'Rain'}
# Streaming row 20 → {'Date_Time': Timestamp('2012-01-01 20:00:00'), 'Temp_C': 3.2, 'Dew_Point_Temp_C': 1.3, 'Rel_Hum_%': 87, 'Wind_Speed_km_h': 19, 'Visibility_km': 25.0, 'Press_kPa': 99.5, 'Weather': 'Cloudy'}
# Streaming row 21 → {'Date_Time': Timestamp('2012-01-01 21:00:00'), 'Temp_C': 4.0, 'Dew_Point_Temp_C': 1.7, 'Rel_Hum_%': 85, 'Wind_Speed_km_h': 20, 'Visibility_km': 25.0, 'Press_kPa': 99.39, 'Weather': 'Cloudy'}
# Streaming row 22 → {'Date_Time': Timestamp('2012-01-01 22:00:00'), 'Temp_C': 4.4, 'Dew_Point_Temp_C': 1.9, 'Rel_Hum_%': 84, 'Wind_Speed_km_h': 24, 'Visibility_km': 19.3, 'Press_kPa': 99.32, 'Weather': 'Rain Showers'}
# Streaming row 23 → {'Date_Time': Timestamp('2012-01-01 23:00:00'), 'Temp_C': 5.3, 'Dew_Point_Temp_C': 2.0, 'Rel_Hum_%': 79, 'Wind_Speed_km_h': 30, 'Visibility_km': 25.0, 'Press_kPa': 99.31, 'Weather': 'Cloudy'}
# ⚠️ ALERT: High temperature detected at 2012-01-01 23:00:00 - 5.3°C
# Streaming row 24 → {'Date_Time': Timestamp('2012-01-02 00:00:00'), 'Temp_C': 5.2, 'Dew_Point_Temp_C': 1.5, 'Rel_Hum_%': 77, 'Wind_Speed_km_h': 35, 'Visibility_km': 25.0, 'Press_kPa': 99.26, 'Weather': 'Rain Showers'}
# ⚠️ ALERT: High temperature detected at 2012-01-02 00:00:00 - 5.2°C
# Streaming row 25 → {'Date_Time': Timestamp('2012-01-02 01:00:00'), 'Temp_C': 4.6, 'Dew_Point_Temp_C': 0.0, 'Rel_Hum_%': 72, 'Wind_Speed_km_h': 39, 'Visibility_km': 25.0, 'Press_kPa': 99.26, 'Weather': 'Cloudy'}
# Streaming row 26 → {'Date_Time': Timestamp('2012-01-02 02:00:00'), 'Temp_C': 3.9, 'Dew_Point_Temp_C': -0.9, 'Rel_Hum_%': 71, 'Wind_Speed_km_h': 32, 'Visibility_km': 25.0, 'Press_kPa': 99.26, 'Weather': 'Mostly Cloudy'}
# Streaming row 27 → {'Date_Time': Timestamp('2012-01-02 03:00:00'), 'Temp_C': 3.7, 'Dew_Point_Temp_C': -1.5, 'Rel_Hum_%': 69, 'Wind_Speed_km_h': 33, 'Visibility_km': 25.0, 'Press_kPa': 99.3, 'Weather': 'Mostly Cloudy'}
# Streaming row 28 → {'Date_Time': Timestamp('2012-01-02 04:00:00'), 'Temp_C': 2.9, 'Dew_Point_Temp_C': -2.3, 'Rel_Hum_%': 69, 'Wind_Speed_km_h': 32, 'Visibility_km': 25.0, 'Press_kPa': 99.26, 'Weather': 'Mostly Cloudy'}
# Streaming row 29 → {'Date_Time': Timestamp('2012-01-02 05:00:00'), 'Temp_C': 2.6, 'Dew_Point_Temp_C': -2.3, 'Rel_Hum_%': 70, 'Wind_Speed_km_h': 32, 'Visibility_km': 25.0, 'Press_kPa': 99.21, 'Weather': 'Mostly Cloudy'}
# Streaming row 30 → {'Date_Time': Timestamp('2012-01-02 06:00:00'), 'Temp_C': 2.3, 'Dew_Point_Temp_C': -2.6, 'Rel_Hum_%': 70, 'Wind_Speed_km_h': 26, 'Visibility_km': 25.0, 'Press_kPa': 99.18, 'Weather': 'Mostly Cloudy'}
# Streaming row 31 → {'Date_Time': Timestamp('2012-01-02 07:00:00'), 'Temp_C': 2.0, 'Dew_Point_Temp_C': -2.9, 'Rel_Hum_%': 70, 'Wind_Speed_km_h': 33, 'Visibility_km': 25.0, 'Press_kPa': 99.14, 'Weather': 'Mostly Cloudy'}
# Streaming row 32 → {'Date_Time': Timestamp('2012-01-02 08:00:00'), 'Temp_C': 1.9, 'Dew_Point_Temp_C': -3.3, 'Rel_Hum_%': 68, 'Wind_Speed_km_h': 39, 'Visibility_km': 24.1, 'Press_kPa': 99.14, 'Weather': 'Mostly Cloudy'}
# Streaming row 33 → {'Date_Time': Timestamp('2012-01-02 09:00:00'), 'Temp_C': 1.8, 'Dew_Point_Temp_C': -3.7, 'Rel_Hum_%': 67, 'Wind_Speed_km_h': 44, 'Visibility_km': 24.1, 'Press_kPa': 99.14, 'Weather': 'Mostly Cloudy'}
# Streaming row 34 → {'Date_Time': Timestamp('2012-01-02 10:00:00'), 'Temp_C': 1.5, 'Dew_Point_Temp_C': -4.1, 'Rel_Hum_%': 66, 'Wind_Speed_km_h': 43, 'Visibility_km': 24.1, 'Press_kPa': 99.18, 'Weather': 'Mostly Cloudy'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-12-294189744.py in <cell line: 0>()
# ----> 1 stream_with_alert(df)
#
# /tmp/ipython-input-11-2670950843.py in stream_with_alert(data, delay)
#       9         print(f"Streaming row {idx} → {row.to_dict()}")
#      10         alert_high_temp(row)
# ---> 11         time.sleep(delay)
#
# KeyboardInterrupt:
