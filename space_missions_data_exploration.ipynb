# %% [markdown]
# <a href="https://colab.research.google.com/github/Sereenamariyam/Data-Analysis/blob/main/space_missions_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import sqlite3
import pandas as pd

# %%
#fetching data from api's
launches_url = "https://api.spacexdata.com/v4/launches"
rockets_url = "https://api.spacexdata.com/v4/rockets"

# %% [markdown]
# # Step 1: Load SpaceX Launch Data from API
#  ● Use https://api.spacexdata.com/v4/launches
#  ● Extract relevant columns: name, date_utc, success, details, rocket
#  ● Convert date_utc to datetime and extract the year

# %%
#loading launches data
launches = requests.get(launches_url).json()

# %%
#Convert to DataFrame
df1 = pd.DataFrame(launches)

#Extract only the needed columns
df1 = df1[['name', 'date_utc', 'success', 'details', 'rocket']]
df1.head()
# Out:
#           name                  date_utc success  \
# 0    FalconSat  2006-03-24T22:30:00.000Z   False
# 1      DemoSat  2007-03-21T01:10:00.000Z   False
# 2  Trailblazer  2008-08-03T03:34:00.000Z   False
# 3       RatSat  2008-09-28T23:15:00.000Z    True
# 4     RazakSat  2009-07-13T03:35:00.000Z    True
#
#                                              details                    rocket
# 0   Engine failure at 33 seconds and loss of vehicle  5e9d0d95eda69955f709d1eb
# 1  Successful first stage burn and transition to ...  5e9d0d95eda69955f709d1eb
# 2  Residual stage 1 thrust led to collision betwe...  5e9d0d95eda69955f709d1eb
# 3  Ratsat was carried to orbit on the first succe...  5e9d0d95eda69955f709d1eb
# 4                                               None  5e9d0d95eda69955f709d1eb

# %%
# to Convert date_utc and Extract Year
#date_utc is a field (column) in the SpaceX launch API response that represents the date and time
#when a SpaceX rocket launch occurred, in UTC (Coordinated Universal Time) format.
df1['date_utc'] = pd.to_datetime(df1['date_utc'])
df1['year'] = df1['date_utc'].dt.year
df1[['name', 'date_utc', 'year']].head()
# Out:
#           name                  date_utc  year
# 0    FalconSat 2006-03-24 22:30:00+00:00  2006
# 1      DemoSat 2007-03-21 01:10:00+00:00  2007
# 2  Trailblazer 2008-08-03 03:34:00+00:00  2008
# 3       RatSat 2008-09-28 23:15:00+00:00  2008
# 4     RazakSat 2009-07-13 03:35:00+00:00  2009

# %% [markdown]
# # Step 2: Load Rocket Metadata
# ● Use  https://api.spacexdata.com/v4/rockets
# ● Extract id, name, type, active, and stages

# %%
#Load Rocket Metadata
rockets = requests.get(rockets_url).json()

# %%
#Convert to DataFrame
df2 = pd.DataFrame(rockets)
rockets_df = pd.DataFrame(rockets)[['id', 'name', 'type', 'active', 'stages']]
rockets_df
# Out:
#                          id          name    type  active  stages
# 0  5e9d0d95eda69955f709d1eb      Falcon 1  rocket   False       2
# 1  5e9d0d95eda69973a809d1ec      Falcon 9  rocket    True       2
# 2  5e9d0d95eda69974db09d1ed  Falcon Heavy  rocket    True       2
# 3  5e9d0d96eda699382d09d1ee      Starship  rocket   False       2

# %%
df1
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 200                                               None
# 201                                               None
# 202                                               None
# 203                                               None
# 204                                               None
#
#                        rocket  year
# 0    5e9d0d95eda69955f709d1eb  2006
# 1    5e9d0d95eda69955f709d1eb  2007
# 2    5e9d0d95eda69955f709d1eb  2008
# 3    5e9d0d95eda69955f709d1eb  2008
# 4    5e9d0d95eda69955f709d1eb  2009
# ..                        ...   ...
# 200  5e9d0d95eda69973a809d1ec  2022
# 201  5e9d0d95eda69973a809d1ec  2022
# 202  5e9d0d95eda69973a809d1ec  2022
# 203  5e9d0d95eda69974db09d1ed  2022
# 204  5e9d0d95eda69973a809d1ec  2022
#
# [205 rows x 6 columns]

# %%
df2
# Out:
#                           height                        diameter  \
# 0  {'meters': 22.25, 'feet': 73}   {'meters': 1.68, 'feet': 5.5}
# 1  {'meters': 70, 'feet': 229.6}     {'meters': 3.7, 'feet': 12}
# 2  {'meters': 70, 'feet': 229.6}  {'meters': 12.2, 'feet': 39.9}
# 3   {'meters': 118, 'feet': 387}       {'meters': 9, 'feet': 30}
#
#                              mass  \
# 0      {'kg': 30146, 'lb': 66460}
# 1   {'kg': 549054, 'lb': 1207920}
# 2  {'kg': 1420788, 'lb': 3125735}
# 3  {'kg': 1335000, 'lb': 2943000}
#
#                                          first_stage  \
# 0  {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...
# 1  {'thrust_sea_level': {'kN': 7607, 'lbf': 17100...
# 2  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...
# 3  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...
#
#                                         second_stage  \
# 0  {'thrust': {'kN': 31, 'lbf': 7000}, 'payloads'...
# 1  {'thrust': {'kN': 934, 'lbf': 210000}, 'payloa...
# 2  {'thrust': {'kN': 934, 'lbf': 210000}, 'payloa...
# 3  {'thrust': {'kN': 1957, 'lbf': 440000}, 'paylo...
#
#                                              engines  \
# 0  {'isp': {'sea_level': 267, 'vacuum': 304}, 'th...
# 1  {'isp': {'sea_level': 288, 'vacuum': 312}, 'th...
# 2  {'isp': {'sea_level': 288, 'vacuum': 312}, 'th...
# 3  {'isp': {'sea_level': 330, 'vacuum': 380}, 'th...
#
#                                    landing_legs  \
# 0               {'number': 0, 'material': None}
# 1     {'number': 4, 'material': 'carbon fiber'}
# 2    {'number': 12, 'material': 'carbon fiber'}
# 3  {'number': 6, 'material': 'stainless steel'}
#
#                                      payload_weights  \
# 0  [{'id': 'leo', 'name': 'Low Earth Orbit', 'kg'...
# 1  [{'id': 'leo', 'name': 'Low Earth Orbit', 'kg'...
# 2  [{'id': 'leo', 'name': 'Low Earth Orbit', 'kg'...
# 3  [{'id': 'leo', 'name': 'Low Earth Orbit', 'kg'...
#
#                                        flickr_images          name  ...  \
# 0  [https://imgur.com/DaCfMsj.jpg, https://imgur....      Falcon 1  ...
# 1  [https://farm1.staticflickr.com/929/2878733830...      Falcon 9  ...
# 2  [https://farm5.staticflickr.com/4599/385838292...  Falcon Heavy  ...
# 3  [https://live.staticflickr.com/65535/489541389...      Starship  ...
#
#   stages  boosters  cost_per_launch  success_rate_pct  first_flight  \
# 0      2         0          6700000                40    2006-03-24
# 1      2         0         50000000                98    2010-06-04
# 2      2         2         90000000               100    2018-02-06
# 3      2         0          7000000                 0    2021-12-01
#
#                             country company  \
# 0  Republic of the Marshall Islands  SpaceX
# 1                     United States  SpaceX
# 2                     United States  SpaceX
# 3                     United States  SpaceX
#
#                                        wikipedia  \
# 0         https://en.wikipedia.org/wiki/Falcon_1
# 1         https://en.wikipedia.org/wiki/Falcon_9
# 2     https://en.wikipedia.org/wiki/Falcon_Heavy
# 3  https://en.wikipedia.org/wiki/SpaceX_Starship
#
#                                          description                        id
# 0  The Falcon 1 was an expendable launch system p...  5e9d0d95eda69955f709d1eb
# 1  Falcon 9 is a two-stage rocket designed and ma...  5e9d0d95eda69973a809d1ec
# 2  With the ability to lift into orbit over 54 me...  5e9d0d95eda69974db09d1ed
# 3  Starship and Super Heavy Rocket represent a fu...  5e9d0d96eda699382d09d1ee
#
# [4 rows x 22 columns]

# %%
# rename the "rocket" columname in df1 and rename "id" columnname in df2 to rocket_id

df1.rename(columns={'rocket': 'rocket_id'}, inplace=True)
df2.rename(columns={'id': 'rocket_id'}, inplace=True)

# %%
# prompt: using merge function merge  the two dataframe df1 and df2 using "rocket_id" column
 #full outer join – it includes:

# Rows where rocket_id matches in both DataFrames

# Plus rows that exist only in df1 or only in df2 (unmatched values)

#Use how='inner' → only matches

#Use how='outer' → matches + non-matches from both

#Use how='left' → all rows from left DataFrame (df1) + matches from right

#Use how='right' → all rows from right DataFrame (df2) + matches from left
merged_df = pd.merge(df1, df2, on="rocket_id", how="outer")
merged_df
# Out:
#                   name_x                  date_utc success  \
# 0              FalconSat 2006-03-24 22:30:00+00:00   False
# 1                DemoSat 2007-03-21 01:10:00+00:00   False
# 2            Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                 RatSat 2008-09-28 23:15:00+00:00    True
# 4               RazakSat 2009-07-13 03:35:00+00:00    True
# ..                   ...                       ...     ...
# 201           ArabSat 6A 2019-04-11 22:35:00+00:00    True
# 202                STP-2 2019-06-25 03:30:00+00:00    True
# 203              USSF-44 2022-11-01 13:41:00+00:00    None
# 204  Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 205                  NaN                       NaT     NaN
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 201  SpaceX will launch Arabsat 6A to a geostationa...
# 202  Space Test Program 2 is a rideshare managed by...
# 203                                               None
# 204                                               None
# 205                                                NaN
#
#                     rocket_id    year                         height  \
# 0    5e9d0d95eda69955f709d1eb  2006.0  {'meters': 22.25, 'feet': 73}
# 1    5e9d0d95eda69955f709d1eb  2007.0  {'meters': 22.25, 'feet': 73}
# 2    5e9d0d95eda69955f709d1eb  2008.0  {'meters': 22.25, 'feet': 73}
# 3    5e9d0d95eda69955f709d1eb  2008.0  {'meters': 22.25, 'feet': 73}
# 4    5e9d0d95eda69955f709d1eb  2009.0  {'meters': 22.25, 'feet': 73}
# ..                        ...     ...                            ...
# 201  5e9d0d95eda69974db09d1ed  2019.0  {'meters': 70, 'feet': 229.6}
# 202  5e9d0d95eda69974db09d1ed  2019.0  {'meters': 70, 'feet': 229.6}
# 203  5e9d0d95eda69974db09d1ed  2022.0  {'meters': 70, 'feet': 229.6}
# 204  5e9d0d95eda69974db09d1ed  2022.0  {'meters': 70, 'feet': 229.6}
# 205  5e9d0d96eda699382d09d1ee     NaN   {'meters': 118, 'feet': 387}
#
#                            diameter                            mass  \
# 0     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 1     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 2     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 3     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 4     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# ..                              ...                             ...
# 201  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 202  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 203  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 204  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 205       {'meters': 9, 'feet': 30}  {'kg': 1335000, 'lb': 2943000}
#
#                                            first_stage  ... active stages  \
# 0    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 1    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 2    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 3    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 4    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# ..                                                 ...  ...    ...    ...
# 201  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 202  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 203  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 204  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 205  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...  ...  False      2
#
#     boosters cost_per_launch success_rate_pct first_flight  \
# 0          0         6700000               40   2006-03-24
# 1          0         6700000               40   2006-03-24
# 2          0         6700000               40   2006-03-24
# 3          0         6700000               40   2006-03-24
# 4          0         6700000               40   2006-03-24
# ..       ...             ...              ...          ...
# 201        2        90000000              100   2018-02-06
# 202        2        90000000              100   2018-02-06
# 203        2        90000000              100   2018-02-06
# 204        2        90000000              100   2018-02-06
# 205        0         7000000                0   2021-12-01
#
#                               country  company  \
# 0    Republic of the Marshall Islands   SpaceX
# 1    Republic of the Marshall Islands   SpaceX
# 2    Republic of the Marshall Islands   SpaceX
# 3    Republic of the Marshall Islands   SpaceX
# 4    Republic of the Marshall Islands   SpaceX
# ..                                ...      ...
# 201                     United States   SpaceX
# 202                     United States   SpaceX
# 203                     United States   SpaceX
# 204                     United States   SpaceX
# 205                     United States   SpaceX
#
#                                          wikipedia  \
# 0           https://en.wikipedia.org/wiki/Falcon_1
# 1           https://en.wikipedia.org/wiki/Falcon_1
# 2           https://en.wikipedia.org/wiki/Falcon_1
# 3           https://en.wikipedia.org/wiki/Falcon_1
# 4           https://en.wikipedia.org/wiki/Falcon_1
# ..                                             ...
# 201     https://en.wikipedia.org/wiki/Falcon_Heavy
# 202     https://en.wikipedia.org/wiki/Falcon_Heavy
# 203     https://en.wikipedia.org/wiki/Falcon_Heavy
# 204     https://en.wikipedia.org/wiki/Falcon_Heavy
# 205  https://en.wikipedia.org/wiki/SpaceX_Starship
#
#                                            description
# 0    The Falcon 1 was an expendable launch system p...
# 1    The Falcon 1 was an expendable launch system p...
# 2    The Falcon 1 was an expendable launch system p...
# 3    The Falcon 1 was an expendable launch system p...
# 4    The Falcon 1 was an expendable launch system p...
# ..                                                 ...
# 201  With the ability to lift into orbit over 54 me...
# 202  With the ability to lift into orbit over 54 me...
# 203  With the ability to lift into orbit over 54 me...
# 204  With the ability to lift into orbit over 54 me...
# 205  Starship and Super Heavy Rocket represent a fu...
#
# [206 rows x 27 columns]

# %% [markdown]
# # Step 4: Add Simulated Country Information
# ● Add a new column country and randomly assign one of these values:
# ['USA', 'Russia', 'India', 'China', 'France']

# %%
import random

# Add random country to each row
merged_df['country'] = [random.choice(['USA', 'Russia', 'India', 'China', 'France']) for _ in range(len(merged_df))]

# Show first few rows
merged_df
# Out:
#                   name_x                  date_utc success  \
# 0              FalconSat 2006-03-24 22:30:00+00:00   False
# 1                DemoSat 2007-03-21 01:10:00+00:00   False
# 2            Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                 RatSat 2008-09-28 23:15:00+00:00    True
# 4               RazakSat 2009-07-13 03:35:00+00:00    True
# ..                   ...                       ...     ...
# 201           ArabSat 6A 2019-04-11 22:35:00+00:00    True
# 202                STP-2 2019-06-25 03:30:00+00:00    True
# 203              USSF-44 2022-11-01 13:41:00+00:00    None
# 204  Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 205                  NaN                       NaT     NaN
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 201  SpaceX will launch Arabsat 6A to a geostationa...
# 202  Space Test Program 2 is a rideshare managed by...
# 203                                               None
# 204                                               None
# 205                                                NaN
#
#                     rocket_id    year                         height  \
# 0    5e9d0d95eda69955f709d1eb  2006.0  {'meters': 22.25, 'feet': 73}
# 1    5e9d0d95eda69955f709d1eb  2007.0  {'meters': 22.25, 'feet': 73}
# 2    5e9d0d95eda69955f709d1eb  2008.0  {'meters': 22.25, 'feet': 73}
# 3    5e9d0d95eda69955f709d1eb  2008.0  {'meters': 22.25, 'feet': 73}
# 4    5e9d0d95eda69955f709d1eb  2009.0  {'meters': 22.25, 'feet': 73}
# ..                        ...     ...                            ...
# 201  5e9d0d95eda69974db09d1ed  2019.0  {'meters': 70, 'feet': 229.6}
# 202  5e9d0d95eda69974db09d1ed  2019.0  {'meters': 70, 'feet': 229.6}
# 203  5e9d0d95eda69974db09d1ed  2022.0  {'meters': 70, 'feet': 229.6}
# 204  5e9d0d95eda69974db09d1ed  2022.0  {'meters': 70, 'feet': 229.6}
# 205  5e9d0d96eda699382d09d1ee     NaN   {'meters': 118, 'feet': 387}
#
#                            diameter                            mass  \
# 0     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 1     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 2     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 3     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# 4     {'meters': 1.68, 'feet': 5.5}      {'kg': 30146, 'lb': 66460}
# ..                              ...                             ...
# 201  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 202  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 203  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 204  {'meters': 12.2, 'feet': 39.9}  {'kg': 1420788, 'lb': 3125735}
# 205       {'meters': 9, 'feet': 30}  {'kg': 1335000, 'lb': 2943000}
#
#                                            first_stage  ... active stages  \
# 0    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 1    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 2    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 3    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# 4    {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...  ...  False      2
# ..                                                 ...  ...    ...    ...
# 201  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 202  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 203  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 204  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...  ...   True      2
# 205  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...  ...  False      2
#
#     boosters cost_per_launch success_rate_pct first_flight country  company  \
# 0          0         6700000               40   2006-03-24  Russia   SpaceX
# 1          0         6700000               40   2006-03-24     USA   SpaceX
# 2          0         6700000               40   2006-03-24     USA   SpaceX
# 3          0         6700000               40   2006-03-24   India   SpaceX
# 4          0         6700000               40   2006-03-24   India   SpaceX
# ..       ...             ...              ...          ...     ...      ...
# 201        2        90000000              100   2018-02-06   India   SpaceX
# 202        2        90000000              100   2018-02-06     USA   SpaceX
# 203        2        90000000              100   2018-02-06  France   SpaceX
# 204        2        90000000              100   2018-02-06   India   SpaceX
# 205        0         7000000                0   2021-12-01  Russia   SpaceX
#
#                                          wikipedia  \
# 0           https://en.wikipedia.org/wiki/Falcon_1
# 1           https://en.wikipedia.org/wiki/Falcon_1
# 2           https://en.wikipedia.org/wiki/Falcon_1
# 3           https://en.wikipedia.org/wiki/Falcon_1
# 4           https://en.wikipedia.org/wiki/Falcon_1
# ..                                             ...
# 201     https://en.wikipedia.org/wiki/Falcon_Heavy
# 202     https://en.wikipedia.org/wiki/Falcon_Heavy
# 203     https://en.wikipedia.org/wiki/Falcon_Heavy
# 204     https://en.wikipedia.org/wiki/Falcon_Heavy
# 205  https://en.wikipedia.org/wiki/SpaceX_Starship
#
#                                            description
# 0    The Falcon 1 was an expendable launch system p...
# 1    The Falcon 1 was an expendable launch system p...
# 2    The Falcon 1 was an expendable launch system p...
# 3    The Falcon 1 was an expendable launch system p...
# 4    The Falcon 1 was an expendable launch system p...
# ..                                                 ...
# 201  With the ability to lift into orbit over 54 me...
# 202  With the ability to lift into orbit over 54 me...
# 203  With the ability to lift into orbit over 54 me...
# 204  With the ability to lift into orbit over 54 me...
# 205  Starship and Super Heavy Rocket represent a fu...
#
# [206 rows x 27 columns]

# %% [markdown]
# # Step 5: Store Merged Data in SQLite3
# ● Use sqlite3 to create a connection and save the merged DataFrame as a table named
# launches
# ● Table should contain all merged columns including country

# %%
#since column is dict we have to convert strings so the below code wont work
'''  Connect to SQLite3 database
error

# Save the merged DataFrame to a table named 'launches'
merged_df.to_sql('launches', conn, if_exists='replace', index=False)

# Close the connection
conn.close()''' #since column is dict we have to convert strings so
# Out:
# "  Connect to SQLite3 database\nerror\n\n# Save the merged DataFrame to a table named 'launches'\nmerged_df.to_sql('launches', conn, if_exists='replace', index=False)\n\n# Close the connection\nconn.close()"

# %%
# Check datatypes of all columns
print(merged_df.dtypes)
# Out:
# name_x                           object
# date_utc            datetime64[ns, UTC]
# success                          object
# details                          object
# rocket_id                        object
# year                            float64
# height                           object
# diameter                         object
# mass                             object
# first_stage                      object
# second_stage                     object
# engines                          object
# landing_legs                     object
# payload_weights                  object
# flickr_images                    object
# name_y                           object
# type                             object
# active                             bool
# stages                            int64
# boosters                          int64
# cost_per_launch                   int64
# success_rate_pct                  int64
# first_flight                     object
# country                          object
# company                          object
# wikipedia                        object
# description                      object
# dtype: object

# %%
# Check which columns contain dicts/lists to convert to strings
for col in merged_df.columns:
    if merged_df[col].apply(lambda x: isinstance(x, (dict, list))).any():
        print(f"⚠️ Column '{col}' contains dict or list values.")
# Out:
# ⚠️ Column 'height' contains dict or list values.
# ⚠️ Column 'diameter' contains dict or list values.
# ⚠️ Column 'mass' contains dict or list values.
# ⚠️ Column 'first_stage' contains dict or list values.
# ⚠️ Column 'second_stage' contains dict or list values.
# ⚠️ Column 'engines' contains dict or list values.
# ⚠️ Column 'landing_legs' contains dict or list values.
# ⚠️ Column 'payload_weights' contains dict or list values.
# ⚠️ Column 'flickr_images' contains dict or list values.

# %%
import pandas as pd
import sqlite3
import json

# Step 1: Convert dict or list columns to string (JSON format)
for col in merged_df.columns:
    if merged_df[col].apply(lambda x: isinstance(x, (dict, list))).any():
        merged_df[col] = merged_df[col].apply(lambda x: json.dumps(x) if isinstance(x, (dict, list)) else x)

# %%
# Step 2: Create SQLite connection
conn = sqlite3.connect("spacex_data.db")

# Step 3: Save the converted DataFrame to a table named 'launches'
merged_df.to_sql("launches", conn, if_exists="replace", index=False)


print("✅ Merged data (with complex columns converted) saved to SQLite.")
# Out:
# ✅ Merged data (with complex columns converted) saved to SQLite.

# %%
pd.read_sql_query("SELECT * FROM launches", conn)
# Out:
#                   name_x                   date_utc  success  \
# 0              FalconSat  2006-03-24 22:30:00+00:00      0.0
# 1                DemoSat  2007-03-21 01:10:00+00:00      0.0
# 2            Trailblazer  2008-08-03 03:34:00+00:00      0.0
# 3                 RatSat  2008-09-28 23:15:00+00:00      1.0
# 4               RazakSat  2009-07-13 03:35:00+00:00      1.0
# ..                   ...                        ...      ...
# 201           ArabSat 6A  2019-04-11 22:35:00+00:00      1.0
# 202                STP-2  2019-06-25 03:30:00+00:00      1.0
# 203              USSF-44  2022-11-01 13:41:00+00:00      NaN
# 204  Viasat-3 & Arcturus  2022-12-01 00:00:00+00:00      NaN
# 205                 None                       None      NaN
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 201  SpaceX will launch Arabsat 6A to a geostationa...
# 202  Space Test Program 2 is a rideshare managed by...
# 203                                               None
# 204                                               None
# 205                                               None
#
#                     rocket_id    year                         height  \
# 0    5e9d0d95eda69955f709d1eb  2006.0  {"meters": 22.25, "feet": 73}
# 1    5e9d0d95eda69955f709d1eb  2007.0  {"meters": 22.25, "feet": 73}
# 2    5e9d0d95eda69955f709d1eb  2008.0  {"meters": 22.25, "feet": 73}
# 3    5e9d0d95eda69955f709d1eb  2008.0  {"meters": 22.25, "feet": 73}
# 4    5e9d0d95eda69955f709d1eb  2009.0  {"meters": 22.25, "feet": 73}
# ..                        ...     ...                            ...
# 201  5e9d0d95eda69974db09d1ed  2019.0  {"meters": 70, "feet": 229.6}
# 202  5e9d0d95eda69974db09d1ed  2019.0  {"meters": 70, "feet": 229.6}
# 203  5e9d0d95eda69974db09d1ed  2022.0  {"meters": 70, "feet": 229.6}
# 204  5e9d0d95eda69974db09d1ed  2022.0  {"meters": 70, "feet": 229.6}
# 205  5e9d0d96eda699382d09d1ee     NaN   {"meters": 118, "feet": 387}
#
#                            diameter                            mass  \
# 0     {"meters": 1.68, "feet": 5.5}      {"kg": 30146, "lb": 66460}
# 1     {"meters": 1.68, "feet": 5.5}      {"kg": 30146, "lb": 66460}
# 2     {"meters": 1.68, "feet": 5.5}      {"kg": 30146, "lb": 66460}
# 3     {"meters": 1.68, "feet": 5.5}      {"kg": 30146, "lb": 66460}
# 4     {"meters": 1.68, "feet": 5.5}      {"kg": 30146, "lb": 66460}
# ..                              ...                             ...
# 201  {"meters": 12.2, "feet": 39.9}  {"kg": 1420788, "lb": 3125735}
# 202  {"meters": 12.2, "feet": 39.9}  {"kg": 1420788, "lb": 3125735}
# 203  {"meters": 12.2, "feet": 39.9}  {"kg": 1420788, "lb": 3125735}
# 204  {"meters": 12.2, "feet": 39.9}  {"kg": 1420788, "lb": 3125735}
# 205       {"meters": 9, "feet": 30}  {"kg": 1335000, "lb": 2943000}
#
#                                            first_stage  ... active stages  \
# 0    {"thrust_sea_level": {"kN": 420, "lbf": 94000}...  ...      0      2
# 1    {"thrust_sea_level": {"kN": 420, "lbf": 94000}...  ...      0      2
# 2    {"thrust_sea_level": {"kN": 420, "lbf": 94000}...  ...      0      2
# 3    {"thrust_sea_level": {"kN": 420, "lbf": 94000}...  ...      0      2
# 4    {"thrust_sea_level": {"kN": 420, "lbf": 94000}...  ...      0      2
# ..                                                 ...  ...    ...    ...
# 201  {"thrust_sea_level": {"kN": 22819, "lbf": 5130...  ...      1      2
# 202  {"thrust_sea_level": {"kN": 22819, "lbf": 5130...  ...      1      2
# 203  {"thrust_sea_level": {"kN": 22819, "lbf": 5130...  ...      1      2
# 204  {"thrust_sea_level": {"kN": 22819, "lbf": 5130...  ...      1      2
# 205  {"thrust_sea_level": {"kN": 128000, "lbf": 287...  ...      0      2
#
#     boosters cost_per_launch success_rate_pct first_flight country  company  \
# 0          0         6700000               40   2006-03-24  Russia   SpaceX
# 1          0         6700000               40   2006-03-24     USA   SpaceX
# 2          0         6700000               40   2006-03-24     USA   SpaceX
# 3          0         6700000               40   2006-03-24   India   SpaceX
# 4          0         6700000               40   2006-03-24   India   SpaceX
# ..       ...             ...              ...          ...     ...      ...
# 201        2        90000000              100   2018-02-06   India   SpaceX
# 202        2        90000000              100   2018-02-06     USA   SpaceX
# 203        2        90000000              100   2018-02-06  France   SpaceX
# 204        2        90000000              100   2018-02-06   India   SpaceX
# 205        0         7000000                0   2021-12-01  Russia   SpaceX
#
#                                          wikipedia  \
# 0           https://en.wikipedia.org/wiki/Falcon_1
# 1           https://en.wikipedia.org/wiki/Falcon_1
# 2           https://en.wikipedia.org/wiki/Falcon_1
# 3           https://en.wikipedia.org/wiki/Falcon_1
# 4           https://en.wikipedia.org/wiki/Falcon_1
# ..                                             ...
# 201     https://en.wikipedia.org/wiki/Falcon_Heavy
# 202     https://en.wikipedia.org/wiki/Falcon_Heavy
# 203     https://en.wikipedia.org/wiki/Falcon_Heavy
# 204     https://en.wikipedia.org/wiki/Falcon_Heavy
# 205  https://en.wikipedia.org/wiki/SpaceX_Starship
#
#                                            description
# 0    The Falcon 1 was an expendable launch system p...
# 1    The Falcon 1 was an expendable launch system p...
# 2    The Falcon 1 was an expendable launch system p...
# 3    The Falcon 1 was an expendable launch system p...
# 4    The Falcon 1 was an expendable launch system p...
# ..                                                 ...
# 201  With the ability to lift into orbit over 54 me...
# 202  With the ability to lift into orbit over 54 me...
# 203  With the ability to lift into orbit over 54 me...
# 204  With the ability to lift into orbit over 54 me...
# 205  Starship and Super Heavy Rocket represent a fu...
#
# [206 rows x 27 columns]

# %%
# when we Check which columns contain dicts/lists again, nothing is displayed. Hence no more columns in dict/list
for col in merged_df.columns:
    if merged_df[col].apply(lambda x: isinstance(x, (dict, list))).any():
        print(f"⚠️ Column '{col}' contains dict or list values.")

# %% [markdown]
# # Step 6: Run SQL Queries on the Data to analyze
# 1. Launches by Country
# 2. Which year had the highest number of launches?
# 3. Top 5 Missions by Launch Count

# %%
# prompt: Step 6: Run SQL Queries on the Data to analyze
# 1. Launches by Country
# 2. Which year had the highest number of launches?


query1 = """
SELECT country, COUNT(*) AS launch_count
FROM launches
GROUP BY country
ORDER BY launch_count DESC;
"""
pd.read_sql(query1, conn)
# Out:
#   country  launch_count
# 0  Russia            48
# 1   China            44
# 2   India            39
# 3     USA            38
# 4  France            37

# %%
# 2. Which year had the highest number of launches?
query2 = """
SELECT year, COUNT(*) AS launch_count
FROM launches
GROUP BY year
ORDER BY launch_count DESC
LIMIT 1;
"""
pd.read_sql(query2, conn)
# Out:
#      year  launch_count
# 0  2022.0            62

# %%
# 3. Top 5 Missions by Launch Count
query3 = """
SELECT name_x AS mission_name, COUNT(*) AS times_launched
FROM launches
GROUP BY mission_name
ORDER BY times_launched DESC
LIMIT 5;
"""
pd.read_sql(query3, conn)
# Out:
#                 mission_name  times_launched
# 0  ispace Mission 1 & Rashid               1
# 1                       ZUMA               1
# 2     WorldView Legion 1 & 2               1
# 3        Viasat-3 & Arcturus               1
# 4                    USSF-44               1
